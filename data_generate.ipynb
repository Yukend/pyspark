# %%
###### PATIENT DATA GENERATOR ######


from concurrent.futures import ThreadPoolExecutor
from faker import Faker
import random

fake = Faker()
file = open("patient.csv", "a")


def generate_patient_data(_):
    patient_id = "PAT" + str(random.randrange(10000, 99999))
    first_name = fake.first_name()
    last_name = fake.last_name()
    date_of_birth = fake.date_of_birth(minimum_age=18, maximum_age=80).strftime('%Y-%m-%d')
    gender = random.choice(['Male', 'Female'])
    phone_number = random.randint(6000000000, 9999999999)
    email = fake.email()
    diagnosis = random.choice(['Headache', 'Fever', 'Cough', 'Back Pain', 'Sprained Ankle', 'Sore Throat', 'Cold', 'Fatigue', 'Hypertension'])
    admission_date = fake.date_this_decade().strftime('%Y-%m-%d')
    discharged = random.choice([True, False])
    organization = "ORG" + str(random.randint(1000, 1999))
    practitioner = "PRAC" + str(random.randint(100, 199))
    address = "ADRS" + str(random.randint(10000, 24999))


    return f"{patient_id},{first_name},{last_name},{date_of_birth},{gender},{address},{phone_number},{email},{diagnosis},{admission_date},{discharged},{organization},{practitioner}"

if __name__ == "__main__":
    num_records = 10000

    with ThreadPoolExecutor() as executor:
        # Use list comprehension to generate 10,000 records using 10 threads
        insert_queries = list(executor.map(generate_patient_data, range(num_records)))

    # Print the generated insert queries
    for query in insert_queries:
        file.write(query + "\n")

# %%
###### ORGANIZATION DATA GENERATOR ######


from concurrent.futures import ThreadPoolExecutor
from faker import Faker
import random

fake = Faker()
file = open("organization.csv", "a")


def generate_organization_data(_):
    name = fake.company().replace(",", "")
    phone_number = random.randint(6000000000, 9999999999)
    email = fake.email()
    active_status = random.choice([True, False])
    organization_id = "ORG" + str(random.randint(100, 199))
    address = "ADRS" + str(random.randint(24999, 25999))

    return f"{organization_id},{name},{phone_number},{email},{active_status},{address}"

if __name__ == "__main__":
    num_records = 100

    with ThreadPoolExecutor() as executor:
        # Use list comprehension to generate 10,000 records using 10 threads
        insert_queries = list(executor.map(generate_organization_data, range(num_records)))

    # Print the generated insert queries
    for query in insert_queries:
        file.write(query + "\n")
# Out:
# ORG165,Miller Ward and Medina,8676796944,perezjasmine@example.net,False,ADRS25244
# ORG175,Rios Parker and Carpenter,9440931445,alyssadavis@example.org,True,ADRS25574
# ORG148,Fernandez-Figueroa,6819887401,deborahvargas@example.org,False,ADRS25912
# ORG155,Barton-Cole,6631040369,russell42@example.org,False,ADRS25333
# ORG102,Hester Group,7380217384,steven14@example.net,False,ADRS25084
# ORG100,Johnson-Garcia,9007210171,michael88@example.net,False,ADRS25343
# ORG128,Everett Matthews and Roach,8099150678,mmartin@example.org,True,ADRS25035
# ORG165,Smith-Cooke,8635654639,anthonywalsh@example.net,True,ADRS25561
# ORG179,Willis and Sons,9241594064,austinmartin@example.net,False,ADRS25078
# ORG121,Peterson-Lee,7547887305,lopezwayne@example.com,False,ADRS25644
# ORG100,Phillips Ltd,9338286729,uedwards@example.org,False,ADRS25728
# ORG126,Mcguire Johnson and Cain,8598334162,suzanne97@example.org,False,ADRS25553
# ORG177,Hart Espinoza and Buck,8269811327,copelandjoshua@example.net,True,ADRS25499
# ORG180,Rodriguez Adams and Blackwell,9035260188,peter64@example.org,True,ADRS25630
# ORG178,Everett and Sons,8162856955,stephaniemiller@example.com,True,ADRS25584
# ORG148,Jackson and Sons,7732532360,lisa09@example.com,True,ADRS25157
# ORG138,Wise PLC,8585525278,stephanie36@example.com,True,ADRS25253
# ORG142,Stone Holt and Carter,8388980957,ejones@example.net,False,ADRS25892
# ORG142,Watson Everett and Holland,9816596931,hadams@example.net,False,ADRS25157
# ORG193,Mcdonald-Lin,9186269199,lawrence59@example.org,True,ADRS25812
# ORG120,Maddox Group,9773660562,tammy35@example.org,False,ADRS25394
# ORG185,Le French and Harrison,8106157757,greyes@example.net,True,ADRS25580
# ORG197,Stephenson-Wilson,8214420106,aedwards@example.com,False,ADRS25928
# ORG105,Harrell Inc,7704928032,hoganbrenda@example.com,False,ADRS25837
# ORG188,Tucker Smith and Hudson,8180519065,amandabrown@example.net,False,ADRS25245
# ORG146,Williams Guzman and Beard,8062688918,michelle13@example.org,True,ADRS25460
# ORG181,Williams-Hamilton,7608819601,tricia59@example.org,True,ADRS25957
# ORG114,Garcia-Young,9428533227,ewells@example.com,True,ADRS25131
# ORG114,Miller-Fitzgerald,7303555662,butlerchristine@example.com,False,ADRS25788
# ORG192,Guerra PLC,9657997445,gonzalezraymond@example.org,True,ADRS25608
# ORG188,Stanley Wang and Zamora,8700993282,pgamble@example.org,False,ADRS25344
# ORG169,Bond Ltd,9824017009,heidirichardson@example.org,True,ADRS25703
# ORG143,Anderson Inc,9866606258,tarmstrong@example.org,True,ADRS25338
# ORG117,Palmer Ltd,6232320697,jason26@example.net,False,ADRS25426
# ORG152,Reed-Flores,7648459835,trevorlowery@example.org,True,ADRS25735
# ORG150,Ray-Nguyen,9598352021,schultznicole@example.com,True,ADRS25453
# ORG137,Oliver-Hinton,6150755427,brendajones@example.org,False,ADRS25418
# ORG197,Howard Bennett and Vaughan,7368898973,oortiz@example.org,False,ADRS25537
# ORG170,Everett-Rich,9422752658,linda25@example.org,False,ADRS25502
# ORG101,Reynolds-Johnson,7840320960,catherinesaunders@example.com,False,ADRS25294
# ORG132,Warren Pearson and Mckay,9349759437,bwilson@example.org,True,ADRS25702
# ORG149,Morales Weaver and Thompson,7769855335,dominguezholly@example.net,True,ADRS25586
# ORG144,Hale Deleon and Williams,9050360257,xknight@example.com,False,ADRS25548
# ORG135,Christensen Bush and Petersen,6079572537,jason09@example.org,False,ADRS25877
# ORG168,Small Palmer and Hatfield,7460765965,chavezstephen@example.com,False,ADRS25015
# ORG129,Rodriguez Ltd,6277814841,jacob89@example.net,False,ADRS25916
# ORG178,Bowers-Steele,8370545707,hernandezchristopher@example.com,True,ADRS25265
# ORG151,Diaz-Richmond,9892460266,ralph43@example.org,False,ADRS25779
# ORG141,Phillips-Boyer,9329840758,sara39@example.org,False,ADRS25411
# ORG157,Young-Williams,9065240153,solomonjessica@example.org,False,ADRS25668
# ORG173,Little Rocha and Holmes,7278267917,joy04@example.net,True,ADRS25750
# ORG155,Dougherty-Moran,9300801284,millershelly@example.net,True,ADRS25447
# ORG103,Sanders Inc,7649586560,mitchell26@example.com,True,ADRS25272
# ORG135,Walker PLC,9451202133,kimberly26@example.com,True,ADRS25737
# ORG173,Hoover LLC,6634625044,garciaandrew@example.org,True,ADRS25876
# ORG199,Long Thomas and Johnson,7757378864,robertvelez@example.org,False,ADRS25871
# ORG119,Shaffer PLC,9504598590,michellegrimes@example.org,True,ADRS25627
# ORG166,Lutz PLC,7761281183,richardjackson@example.net,False,ADRS25107
# ORG111,Fleming Harris and Liu,7676820319,sullivanjesus@example.net,True,ADRS25822
# ORG122,Adams Reyes and Harrington,8281727107,michaellara@example.org,False,ADRS25770
# ORG188,Murphy-Terrell,9622467121,jparker@example.com,True,ADRS25012
# ORG168,Ross Dean and Vargas,7094041869,ochandler@example.net,False,ADRS25491
# ORG157,Schroeder Group,6099669313,eparker@example.org,True,ADRS25869
# ORG189,Taylor and Sons,8454788827,adamsmartin@example.com,False,ADRS25458
# ORG194,Wiggins-Raymond,7864710988,georgesara@example.com,False,ADRS25968
# ORG147,Blake-Ramirez,9852652866,ilang@example.net,True,ADRS25215
# ORG107,Estrada PLC,9888427218,fdoyle@example.org,True,ADRS25632
# ORG121,Cruz Ltd,9571166080,jay47@example.com,True,ADRS25303
# ORG107,Perry Cooper and Foster,7857108632,anthony61@example.org,True,ADRS25915
# ORG167,Garcia Stafford and Carr,8455644535,jamesleonard@example.net,False,ADRS25804
# ORG156,Carter Hill and Everett,8760389183,ericabailey@example.com,True,ADRS25308
# ORG116,Rose Taylor and Stewart,9058086060,frank49@example.net,True,ADRS25623
# ORG116,Mendoza Hines and Adams,7240059183,wilsonsteven@example.net,True,ADRS25680
# ORG121,Cooke Simpson and Gray,9994196771,melissa13@example.net,False,ADRS25126
# ORG199,Cummings-Vaughan,7134448004,gfuentes@example.net,True,ADRS25774
# ORG138,Stone Gonzalez and Hodges,8613512971,yolanda16@example.org,True,ADRS25155
# ORG130,Hogan Group,9731162356,jacob92@example.com,False,ADRS25795
# ORG142,Patterson LLC,6002089140,kcook@example.com,False,ADRS25245
# ORG169,Davis LLC,9112509619,curtistammy@example.com,True,ADRS25009
# ORG141,Brennan-Griffin,8293144877,longamber@example.org,True,ADRS25720
# ORG168,Padilla Conner and Shah,8490611467,helen58@example.org,True,ADRS25366
# ORG145,Hernandez and Sons,7250148607,galvancrystal@example.com,True,ADRS25073
# ORG167,Vega-Wood,9991602829,clinerebecca@example.org,False,ADRS25720
# ORG134,Brady Hall and Thomas,9693156221,jonathansolis@example.com,True,ADRS25975
# ORG113,Perkins-Boyer,7686566420,christopher84@example.org,True,ADRS25758
# ORG167,Moore Stephenson and Mann,7192351480,grush@example.net,False,ADRS25521
# ORG165,Shelton and Sons,9731243703,andrew18@example.net,True,ADRS25894
# ORG172,Klein Ltd,9001833340,pmartinez@example.net,False,ADRS25473
# ORG186,Shelton and Sons,6745806992,hendersoncarolyn@example.org,False,ADRS25172
# ORG199,Williams Nguyen and Walker,6268759886,jasminemendoza@example.com,False,ADRS25794
# ORG104,Ritter Ford and Mcgrath,9601788933,gibbsedward@example.net,True,ADRS25578
# ORG162,Adams Gomez and Stephenson,7734587056,crystal22@example.net,False,ADRS25707
# ORG102,Perkins Inc,7482065440,stevencowan@example.com,False,ADRS25423
# ORG169,Harris and Sons,7551842131,noah09@example.com,True,ADRS25023
# ORG119,Nicholson Campbell and Kelly,7333544677,jessicastrong@example.org,True,ADRS25581
# ORG136,Nelson-Campbell,9292821329,nathan98@example.net,False,ADRS25750
# ORG189,Mendez-Bright,9553093168,huangwillie@example.org,False,ADRS25099
# ORG141,Romero Inc,8491635950,rosalesdavid@example.com,True,ADRS25571
# ORG171,Williams Reyes and Petty,6614900681,morgandeborah@example.net,False,ADRS25361
# ORG159,Stanley Perry and Lang,8073881633,bishoptyler@example.net,False,ADRS25440

# %%
###### PRACTITIONER DATA GENERATOR ######


from concurrent.futures import ThreadPoolExecutor
from faker import Faker
import random

fake = Faker()
file = open("practitioner.csv", "a")


def generate_practitioner_data(_):
    practitioner_id = "PRAC" + str(random.randrange(1000, 1999))
    first_name = fake.first_name()
    last_name = fake.last_name()
    date_of_birth = fake.date_of_birth(minimum_age=18, maximum_age=80).strftime('%Y-%m-%d')
    gender = random.choice(['Male', 'Female'])
    phone_number = random.randint(6000000000, 9999999999)
    email = fake.email()
    active_status = random.choice([True, False])
    organization = "ORG" + str(random.randint(100, 199))
    address = "ADRS" + str(random.randint(25999, 29999))


    return f"{organization},{practitioner_id},{first_name},{last_name},{date_of_birth},{gender},{address},{phone_number},{email},{active_status}"

if __name__ == "__main__":
    num_records = 1000

    with ThreadPoolExecutor() as executor:
        # Use list comprehension to generate 10,000 records using 10 threads
        insert_queries = list(executor.map(generate_practitioner_data, range(num_records)))

    # Print the generated insert queries
    for query in insert_queries:
        file.write(query + "\n")

# %%
from concurrent.futures import ThreadPoolExecutor
from faker import Faker
import random

fake = Faker()
file = open("address.csv", "a")


def generate_address_data(_):
    address_id = "ADRS" + str(random.randrange(10000, 29999))
    street = fake.street_address()
    city = fake.city()
    state = fake.state()
    zip_code = fake.zipcode()
    country = fake.country()
    type= random.choice(["Home", "Home", "Home", "Work"])

    return f"{address_id},{street},{city},{state},{zip_code},{country},{type}"

if __name__ == "__main__":
    num_records = 20000

    with ThreadPoolExecutor() as executor:
        # Use list comprehension to generate 10,000 records using 10 threads
        insert_queries = list(executor.map(generate_address_data, range(num_records)))

    # Print the generated insert queries
    for query in insert_queries:
        file.write(query + "\n")

# %%
from concurrent.futures import ThreadPoolExecutor
from faker import Faker
import random

fake = Faker()
file = open("encounter.csv", "a")

def generate_encounter_data(_):
    encounter_id = "ENC" + str(random.randrange(10000, 29999))
    encounter_date = fake.date_this_decade()
    encounter_type = random.choice(["Checkup", "Emergency", "Follow-up"])
    prescription = fake.sentence()
    practitioner = "PRAC" + str(random.randint(1000, 1999))
    patient = "PAT" + str(random.randint(10000, 19999))

    return f"{encounter_id},{encounter_date},{encounter_type},{prescription},{practitioner},{patient}"

if __name__ == "__main__":
    num_encounters = 20000

    with ThreadPoolExecutor() as executor:
        # Use list comprehension to generate 20,000 encounter records using 10 threads
        encounter_records = list(executor.map(generate_encounter_data, range(num_encounters)))

    # Print the generated encounter records
    for record in encounter_records:
        file.write(record + "\n")

    file.close()

# %%
from faker import Faker
from concurrent.futures import ThreadPoolExecutor
import random

fake = Faker()
file = open("diagnosis.csv", "a")

def generate_diagnosis_data(_):
    diagnosis_id = "DIAG" + str(random.randint(10000, 39999))
    diagnosis_date = fake.date_this_decade()
    diagnosis_type = random.choice(['Headache', 'Fever', 'Cough', 'Back Pain', 'Sprained Ankle', 'Sore Throat', 'Cold', 'Fatigue', 'Hypertension'])
    diagnosis_result = fake.sentence()
    practitioner = "PRAC" + str(random.randint(1000, 1999))
    patient = "PAT" + str(random.randint(10000, 19999))
    encounter = "ENC" + str(random.randint(10000, 29999))

    return f"{diagnosis_id},{patient},{encounter},{practitioner},{diagnosis_date},{diagnosis_type},{diagnosis_result}"

if __name__ == "__main__":
    num_diagnoses = 30000

    with ThreadPoolExecutor() as executor:
        # Use list comprehension to generate 20,000 diagnosis records using 10 threads
        diagnosis_records = list(executor.map(generate_diagnosis_data, range(num_diagnoses)))

    # Print the generated diagnosis records
    for record in diagnosis_records:
        file.write(record + "\n")

    file.close()

# %%
medicine_list = [
    "Alphazide",
    "Synercold",
    "Zylite",
    "Voltabex",
    "Cardioflux",
    "Osteoflow",
    "Glucoplus",
    "Dermazone",
    "Nurodex",
    "RespiraCure",
    "OptiVitale",
    "Gastroguard",
    "ImmunoShield",
    "Neurozen",
    "Oxyflow",
    "DigestiCare",
    "NutaVita",
    "AllerGuard",
    "FlexiCare",
    "OculoClear",
    "Tranquilix",
    "PediaRelief",
    "CardioGuard",
    "DermaRestore",
    "ThermoFlex",
    "SleepSure",
    "JointEase",
    "PulmoVista",
    "NourishPro",
    "UroShield",
    "VitaLume",
    "GastroAid",
    "NeuroCalm",
    "RespiraEase",
    "PediaVita",
    "Tranquility",
    "DigestiPro",
    "OculoBright",
    "ImmunoBoost",
    "NerveGuard",
    "CardioWell",
    "Dermacare",
    "OsteoMax",
    "VitaFuel",
    "FlexiJoint",
    "RespiraFree",
    "GastroCare",
    "ThermoCare",
    "NourishMax",
    "NeuroRelax",
    "SleepEase",
    "JointFlex",
    "CardioPro",
    "DermaGlow",
    "ImmunoPro",
    "DigestaMax",
    "NerveEase",
    "PediaGlo",
    "TranquilEase",
    "VitaGlow",
    "FlexiPro",
    "RespiraMax",
    "GastroEase",
    "NeuroMax",
    "SleepMax",
    "JointMax",
    "PediaMax",
    "CardioMax",
    "DermaMax",
    "ImmunoMax",
    "DigestiMax",
    "NerveMax",
    "OculoMax",
    "TranquilMax",
    "VitaMax",
    "FlexiMax",
    "RespiraPlus",
    "GastroPlus",
    "NeuroPlus",
    "SleepPlus",
    "JointPlus",
    "PediaPlus",
    "CardioPlus",
    "DermaPlus",
    "ImmunoPlus",
    "DigestiPlus",
    "NervePlus",
    "OculoPlus",
    "TranquilPlus",
    "VitaPlus",
    "FlexiPlus",
    "Acenolol",
    "Betacure",
    "Ceflodox",
    "Dexicilin",
    "Epirox",
    "Furoxidone",
    "Gastrocalm",
    "Hemozide",
    "Ibrofen",
    "Juvanol",
    "Ketonex",
    "Lymenix",
    "Monotriptan",
    "Neopril",
    "Oxyclix",
    "Proxidine",
    "Quikfix",
    "Radoxin",
    "Serranex",
    "Tetravita",
    "Uricidol",
    "Vaxiwave",
    "Xenalite",
    "Yumecin",
    "Zolamed",
    "Alphacol",
    "Bioterix",
    "Ceflinex",
    "Dermacure",
    "Eukalix",
    "Fibrinex",
    "Gastrozole",
    "Helidox",
    "Inflamex",
    "Juvanex",
    "Kalmoxin",
    "Lycinex",
    "Maxifex",
    "Nurozone",
    "Oxibex",
    "Pradoxol",
    "Quidolix",
    "Remolin",
    "Seroxol",
    "Taziplex",
    "Uroxid",
    "Ventrex",
    "Xenodox",
    "Yuminol",
    "Ziramed",
    "Amixotin",
    "Biotical",
    "Ceframed",
    "Dexalin",
    "Erythrin",
    "Fibrocal",
    "Gabatex",
    "Heliway",
    "Ibonex",
    "Juvadex",
    "Ketozone",
    "Levadose",
    "Mytexin",
    "Naliflex",
    "Oxitonex",
    "Prazical",
    "Quinomed",
    "Reloxin",
    "Serrapex",
    "Tolvamed",
    "Uricinol",
    "Viozex",
    "Xerolox",
    "Yumizon",
    "Zynoxin",
    "Alphadox",
    "Beximed",
    "Ceftrix",
    "Dexamox",
    "Epitec",
    "Fibronex",
    "Galafix",
    "Hydroxin",
    "Ibonix",
    "Juvamed",
    "Keftrin",
    "Lymedex",
    "Monoflex",
    "Nuprinol",
    "Oxytide",
    "Primexin",
    "Quidinol",
    "Remoxin",
    "Solvadex",
    "Tranoxin",
    "Uzodox",
    "Virexin",
    "Xalitrex",
    "Yumoxin",
    "Zomarin"
]
manufacturers = [
    "MedicoTech Pharmaceuticals",
    "BioGenX Health Solutions",
    "OmniCare Innovations",
    "NovoPharma Industries",
    "VitalMed Labs",
    "Apex Cure Systems",
    "MedLifex Therapeutics",
    "Precision Heal Sciences",
    "Nexus BioHealth",
    "LifeQuest Pharmaceuticals",
    "BioVista Research",
    "Excela PharmaTech",
    "ProMed Innovations",
    "HealSynth Labs",
    "Quantum BioTech",
    "GenoWave Pharmaceuticals",
    "SynthoMed Solutions",
    "EpiGenix BioScience",
    "Zenith Medix Corp",
    "NovaCure PharmaSys"
]

# %%
from concurrent.futures import ThreadPoolExecutor
from faker import Faker
import random
from datetime import datetime, timedelta

# Create a Faker instance
fake = Faker()
file = open("medicine.csv", "a")

# Function to generate synthetic medicine data
def generate_medicine_data(_):
    medicine_id = "MED" + str(random.randrange(100, 299))
    medicine_name = random.choice(medicine_list)
    manufacturer = random.choice(manufacturers)
    dosage_form = random.choice(["Tablet", "Tonic", "Injection", "Powder", "Liquids"])
    strength = round(random.uniform(1, 100), 2)
    unit = random.choice(["100mg", "200mg", "300mg", "400mg", "500mg"])
    quantity = random.randint(1, 1000)
    price = round(random.uniform(1, 1000), 2)
    expiry_date = (datetime.now() + timedelta(days=random.randint(30, 365))).strftime('%Y-%m-%d')

    return f"{medicine_id},{medicine_name},{manufacturer},{dosage_form},{strength},{unit},{quantity},{price},{expiry_date}"

if __name__ == "__main__":
    num_medicines = 200

    with ThreadPoolExecutor() as executor:
        # Use list comprehension to generate 20,000 diagnosis records using 10 threads
        diagnosis_records = list(executor.map(generate_medicine_data, range(num_medicines)))

    # Print the generated diagnosis records
    for record in diagnosis_records:
        file.write(record + "\n")

    file.close()
